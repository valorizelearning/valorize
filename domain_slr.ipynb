# %% [markdown]
# # *Systematic Literature Review*
#
# ## *Review*
#
# ### *Title*
# Collaborative Knowledge Management Framework Based on Smart Engineering for Value-Oriented Higher Education
#
# ### *Description*
# Penelitian ini mengusulkan sebuah Kerangka Kerja Manajemen Pengetahuan Kolaboratif (CKM) yang inovatif untuk menggabungkan Rekayasa Cerdas dengan Manajemen Pengetahuan Kolaboratif di perguruan tinggi. Fokus utamanya bukan sekadar membuat sistem kampus menjadi lebih "pintar" secara digital, tetapi menggunakan kecerdasan sistem tersebut untuk mendukung Pendidikan Berorientasi Nilai yang memfasilitasi pertukaran pengetahuan yang efektif antara dosen dan mahasiswa. Berbeda dengan sistem manajemen kampus konvensional yang hanya berfokus pada transfer pengetahuan. Tujuannya adalah memastikan bahwa integrasi teknologi tidak hanya meningkatkan kompetensi teknis, tetapi juga tetap menjunjung tinggi nilai-nilai kemanusiaan dan etika.
#
# ## *Planning*
#
# ### *Protocol*
#
# #### *Objectives*
#
# *General Objective* (Tujuan Umum)
#
# Merancang dan mengembangkan kerangka kerja Manajemen Pengetahuan Kolaboratif (CKM) berbasis Rekayasa Cerdas (*Smart Engineering*) yang mampu mengintegrasikan peningkatan kompetensi teknis dengan penanaman nilai-nilai etika dan kemanusiaan dalam lingkungan pendidikan tinggi.
#
# *Specific Objectives* (Tujuan Khusus)
#
# 1. Menganalisis Kesenjangan Sistem (*Gap Analysis*): Menganalisis keterbatasan sistem manajemen pengetahuan konvensional di perguruan tinggi saat ini, khususnya dalam kemampuannya mendukung aspek pendidikan karakter dan transfer nilai (value transfer) daripada sekadar transfer data akademik.
#
# 2. Merancang Arsitektur CKM Berbasis Rekayasa Cerdas: Membangun arsitektur sistem CKM yang mengadopsi prinsip *Smart Engineering* untuk memfasilitasi pertukaran pengetahuan yang efektif antara dosen dan mahasiswa. Sistem tidak hanya menilai capaian teknis, tetapi juga mampu mendeteksi, mendorong, dan memvalidasi interaksi yang mencerminkan nilai etika, empati, dan kolaborasi positif.
#
# 3. Mengevaluasi Efektivitas Kerangka Kerja: Menguji validitas dan efektivitas kerangka kerja yang diusulkan untuk memastikan bahwa penerapannya mampu meningkatkan kompetensi *hard skill* (teknis) mahasiswa sekaligus memperkuat *soft skill* (nilai kemanusiaan) dibandingkan dengan metode konvensional.
#
# #### PICOC
#
# Metode PICOC (*Population, Intervention, Comparison, Outcome, Context*) sangat berguna untuk memperjelas batasan masalah dan fokus penelitian
#
# **P - Subjek (Siapa yang diteliti?)**
# Dosen dan Mahasiswa di institusi pendidikan tinggi
#
# **I - Solusi (Apa alat/solusi barunya?)**
# Kerangka Kerja Manajemen Pengetahuan Kolaboratif berbasis Rekayasa Cerdas.
#
# **C - Pembanding (Apa lawannya?)**
# Sistem Manajemen Pengetahuan Konvensional (LMS biasa atau metode transfer ilmu tradisional) yang hanya berfokus pada aspek teknis/akademik tanpa fitur integrasi nilai.
#
# **O - Hasil yang diharapkan (Apa gol nya?)**
# 1. Peningkatan efektivitas pertukaran pengetahuan.
# 2. Terintegrasinya nilai-nilai kemanusiaan dan etika dalam proses teknis.
# 3. Peningkatan kompetensi hard skill dan soft skill.
#
# **C - Konteks lingkungan (Dimana settingnya?)**
# Pendidikan Tinggi yang menerapkan transformasi digital atau pendidikan karakter.
#
# #### Research Questions
#
# "Bagaimana penerapan Kerangka Kerja CKM berbasis Rekayasa Cerdas (I) pada Dosen dan Mahasiswa (P) di lingkungan Pendidikan Tinggi (C-ontext) dalam meningkatkan kompetensi etika dan teknis (O) dibandingkan dengan Sistem Manajemen Pengetahuan Konvensional (C-omparison)?"
#
# #### Keywords and Synonyms
#
# Berdasarkan 4 konsep utama dari judul:
#
# 1. Konsep Intervensi: *Collaborative Knowledge Management* (Aktivitas utamanya)
#
# Keywords
#
# - Collaborative Knowledge Management (CKM)
# - Knowledge Sharing
#
# Synonyms
#
# - Knowledge Transfer (Transfer Pengetahuan)
# - Knowledge Exchange (Pertukaran Pengetahuan)
# - Co-creation of Knowledge (Kokreasi Pengetahuan)
# - Social Knowledge Management
# - Collaborative Learning Environment
# - Organizational Learning
#
# 2. Konsep Intervensi: *Smart Engineering* (metode atau teknologi penggeraknya).
#
# Keywords
#
# - Smart Engineering
# - Smart Systems
#
# Synonyms
#
# - Intelligent Systems (Sistem Cerdas)
# - Artificial Intelligence in Education / AIEd
# - Smart Campus
# - Digital Transformation
# - Industry 4.0 in Education
# - Data-Driven Engineering
# - Adaptive Systems
#
# 3. Konsep Outcome: Value-Oriented (fokus unik/luaran non-teknisnya)
#
# Keywords
#
# - Value-Oriented Education
# - Ethics
#
# Synonyms
#
# - Value-Based Learning
# - Character Building (Pembangunan Karakter)
# - Moral Education
# - Soft Skills
# - Ethical Engineering
# - Human-Centric Education
# - Social Responsibility
# - Affective Domain (Ranah Afektif)
#
# 4. Konsep Populasi: Higher Education (konteks atau tempatnya)
#
# Keywords
#
# - Higher Education
# - University
#
# Synonyms
#
# - Higher Education Institutions (HEI)
# - Tertiary Education
# - Engineering Education (Pendidikan Teknik - spesifik)
# - College
# - Academia
#
# #### Search String
#
# ("Higher Education" OR "Academia" OR "College" OR "Engineering Education" OR "Higher Education Institutions" OR "Tertiary Education" OR "University") AND ("Collaborative Knowledge Management" OR "Co-creation of Knowledge" OR "Collaborative Learning Environment" OR "Knowledge Exchange" OR "Knowledge Sharing" OR "Knowledge Transfer" OR "Organizational Learning" OR "Social Knowledge Management" OR "Smart Engineering" OR "AIEd" OR "Adaptive Systems" OR "Artificial Intelligence in Education" OR "Data-Driven Engineering" OR "Digital Transformation" OR "Industry 4.0 in Education" OR "Intelligent Systems" OR "Smart Campus" OR "Smart Systems") AND ("Value-Oriented Education" OR "Affective Domain" OR "Character Building" OR "Ethical Engineering" OR "Ethics" OR "Human-Centric Education" OR "Moral Education" OR "Social Responsibility" OR "Soft Skills" OR "Value-Based Learning")
#
# #### Sources
#
# Digital Libraries
# ACM Digital Library	http://portal.acm.org
# IEEE Digital Library	http://ieeexplore.ieee.org
# Science@Direct	http://www.sciencedirect.com
# Scopus	http://www.scopus.com
# Springer Link	http://link.springer.com
#
# #### Selection Criteria
#
# | Kategori | Kriteria Inklusi (Diterima) | Kriteria Eksklusi (Ditolak) |
# | :--- | :--- | :--- |
# | **Topik** | Pendidikan Tinggi, Manajemen Pengetahuan, Sistem Cerdas, Pendidikan Nilai. | Pendidikan Dasar (SD/SMP/SMA).|
# | **Intervensi** | Teknologi Smart Engineering, AI, Data Analytics, Collaborative Tools. | Teknologi konvensional/usang tanpa fitur cerdas. |
# | **Outcome** | Dampak pada kolaborasi, etika, nilai moral, soft skills. | Hanya fokus pada efisiensi energi gedung atau nilai ujian semata. |
# | **Tipe Publikasi** | Jurnal Internasional/Nasional, Prosiding Konferensi, Book Chapter. | Artikel opini, berita, blog, abstract-only. |
# | **Tahun** | 5 - 10 Tahun Terakhir (**2015 – 2025**). | Sebelum 2015 (kecuali *grand theory*). |
# | **Bahasa** | Inggris | Bahasa asing lainnya. |
#
# ### Quality Assesment Checklist
#
# | Kode | Pertanyaan Penilaian (Questions) | Pilihan Jawaban (Answers) | Skor (Score) |
# | :--- | :--- | :--- | :--- |
# | **QA1** | Apakah **tujuan** penelitian dan masalah yang ingin diselesaikan dinyatakan dengan jelas? | • Ya (Yes)<br>• Sebagian (Partially)<br>• Tidak (No) | 1.0<br>0.5<br>0 |
# | **QA2** | Apakah **metodologi** penelitian atau arsitektur sistem/framework dijelaskan secara rinci dan dapat direplikasi? | • Ya (Yes)<br>• Sebagian (Partially)<br>• Tidak (No) | 1.0<br>0.5<br>0 |
# | **QA3** | Apakah studi ini secara eksplisit membahas penerapan teknologi cerdas (***Smart Engineering*** / AI / Sistem Adaptif) dalam konteks pendidikan? | • Ya (Yes)<br>• Sebagian (Partially)<br>• Tidak (No) | 1.0<br>0.5<br>0 |
# | **QA4** | Apakah studi ini menyentuh aspek non-teknis seperti kolaborasi, etika, nilai (***values***), atau pembangunan karakter? | • Ya (Yes)<br>• Sebagian (Partially)<br>• Tidak (No) | 1.0<br>0.5<br>0 |
# | **QA5** | Apakah ada bukti **validasi**, pengujian sistem, atau analisis data yang mendukung kesimpulan/efektivitas framework tersebut? | • Ya (Yes)<br>• Sebagian (Partially)<br>• Tidak (No) | 1.0<br>0.5<br>0 |
#
# ### Data Extraction Form
#
# | Field / Data Item | Deskripsi Data | Tipe Data | Values (Pilihan/Contoh Nilai) |
# | :--- | :--- | :--- | :--- |
# | **A. Informasi Umum** | | | |
# | Study ID | Kode unik untuk identifikasi paper. | String / Text | P01, P02, P03, dst. |
# | Title | Judul lengkap artikel penelitian. | String / Text | (Isi judul paper) |
# | Author(s) | Nama penulis atau peneliti. | String / Text | (Isi nama penulis) |
# | Publication Year | Tahun terbit artikel. | Integer | 2015, 2020, 2024, dst. |
# | Country / Region | Lokasi geografis penelitian dilakukan. | String / Text | Indonesia, USA, Europe, Global, dst. |
# | **B. Metodologi** | | | |
# | Research Method | Metode yang digunakan dalam penelitian. | Categorical | • Case Study<br>• Experiment<br>• Survey<br>• Design Science / Prototyping<br>• SLR (Literature Review)<br>• Mixed Method |
# | Context / Setting | Level pendidikan atau fakultas tempat studi dilakukan. | Categorical | • Higher Education (General)<br>• Engineering Faculty<br>• Vocational / Polytechnic<br>• Computer Science Dept. |
# | **C. Smart Engineering** | *(Intervensi Teknologi)* | | |
# | Technology Used | Teknologi cerdas spesifik yang diterapkan dalam sistem/framework. | Multiple Select | • AI / Machine Learning<br>• Data Mining / Analytics<br>• IoT (Internet of Things)<br>• Cloud Computing<br>• Semantic Web / Ontology<br>• Mobile Apps<br>• Other |
# | System Architecture | Apakah paper menyediakan diagram arsitektur sistem? | Boolean | • Yes<br>• No |
# | **D. Knowledge Management** | *(Proses KM)* | | |
# | KM Process Focus | Tahapan KM yang difasilitasi oleh sistem. | Multiple Select | • Knowledge Creation<br>• Knowledge Sharing / Transfer<br>• Knowledge Storage<br>• Knowledge Application |
# | Collaboration Type | Bentuk kolaborasi yang terjadi dalam sistem. | Categorical | • Student-Student<br>• Student-Lecturer<br>• Group Project<br>• Interdisciplinary |
# | **E. Value-Oriented** | *(Outcome / Luaran)* | | |
# | Values Addressed | Nilai-nilai (*values*) atau *soft skills* yang menjadi fokus luaran. | Multiple Select | • Ethics (Etika)<br>• Teamwork/Collaboration<br>• Empathy<br>• Social Responsibility<br>• Critical Thinking<br>• Leadership |
# | Impact Result | Hasil evaluasi terhadap peningkatan nilai/karakter. | String / Text | • Positive Significant<br>• Positive but Weak<br>• No Impact<br>• Not Measured |
# | **F. Temuan Tambahan** | | | |
# | Challenges / Gaps | Tantangan atau hambatan yang disebutkan peneliti. | String / Text | (Teks bebas, misal: infrastruktur, literasi digital) |
# | Key Findings | Kesimpulan utama dari penelitian tersebut. | String / Text | (Ringkasan hasil temuan) |
#
# ---
#
# ## Keterangan Tipe Data
# * **String / Text:** Isian bebas berupa teks (kalimat atau frasa).
# * **Integer:** Angka bulat.
# * **Categorical:** Pilihan kategori tunggal (pilih satu yang paling dominan).
# * **Multiple Select:** Pilihan kategori di mana satu paper bisa memiliki lebih dari satu jawaban.
# * **Boolean:** Pilihan biner (Ya/Tidak).
#
# ## *Conducting*
#
# Document results: 131.242
#
# Filter:
#
# - 2020 s.d 2026
# - Subject area: Computer science
# - Document type: Article
# - Publication stage: Final
# - Source type: Journal
# - Language: English
# - Open Access: Limited to all open access
#
# ( "Higher Education" OR "Academia" OR "College" OR "Engineering Education" OR "Higher Education Institutions" OR "Tertiary Education" OR "University" ) AND ( "Collaborative Knowledge Management" OR "Co-creation of Knowledge" OR "Collaborative Learning Environment" OR "Knowledge Exchange" OR "Knowledge Sharing" OR "Knowledge Transfer" OR "Organizational Learning" OR "Social Knowledge Management" OR "Smart Engineering" OR "AIEd" OR "Adaptive Systems" OR "Artificial Intelligence in Education" OR "Data-Driven Engineering" OR "Digital Transformation" OR "Industry 4.0 in Education" OR "Intelligent Systems" OR "Smart Campus" OR "Smart Systems" ) AND ( "Value-Oriented Education" OR "Affective Domain" OR "Character Building" OR "Ethical Engineering" OR "Ethics" OR "Human-Centric Education" OR "Moral Education" OR "Social Responsibility" OR "Soft Skills" OR "Value-Based Learning" ) AND PUBYEAR > 2019 AND PUBYEAR < 2027 AND ( LIMIT-TO ( SRCTYPE , "j" ) ) AND ( LIMIT-TO ( OA , "all" ) ) AND ( LIMIT-TO ( PUBSTAGE , "final" ) ) AND ( LIMIT-TO ( SUBJAREA , "COMP" ) ) AND ( LIMIT-TO ( DOCTYPE , "ar" ) ) AND ( LIMIT-TO ( LANGUAGE , "English" ) )
#
# Document results: 10.329
# Yang berhasil di import: 9946
#
# BibTeX file [Klik Disini](assets/scopus/scopus_export_Dec%209-2025_7ae9db48-2320-42bc-a984-d0a18b4f58ea.bib)
#
# ## *Reporting*
